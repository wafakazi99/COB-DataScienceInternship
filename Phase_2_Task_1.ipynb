# %% [markdown]
# 1.	Analyze the dataset and create graphs using seaborn and matplotlib. Dataset :- https://docs.google.com/spreadsheets/d/e/2PACX-1vTSS-TcErkXNk8KB0AlijhitwetxeHD2M3R0HJl2QPMAyFq0fxFX4PFKnzAWLDnratIz67DNL6GsZnV/pub?output=csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('phase2- task1-clean data set.csv')


fig, ax = plt.subplots(figsize=(8, 4))

sns.countplot(x='type', data=data, ax=ax)
ax.set_title('Count of Movies and TV Shows')

plt.show()

# %%
df.describe()
# Out:
#             index  release_year
# count  8228.00000   8228.000000
# mean   4401.87895   2016.042052
# std    2551.74535      4.220889
# min       0.00000   2001.000000
# 25%    2205.75000   2015.000000
# 50%    4339.50000   2017.000000
# 75%    6681.25000   2019.000000
# max    8789.00000   2021.000000

# %%
sns.boxplot(df["release_year"])
plt.ylabel(" Year")
plt.title("Boxplot")
plt.show()

# %%
df = df[df["release_year"] > 2000]
df.reset_index(inplace=True)


# Displaying the boxplot
sns.boxplot(df["release_year"])
plt.ylabel("Release Year")
plt.title("Boxplot for Release Year")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
fig.suptitle("Top 10 Countries")

sns.countplot(x='country', data=data, order=data['country'].value_counts().iloc[:10].index, ax=ax)
ax.set_title('Top 10 Countries')
ax.tick_params(axis='x', rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
fig.suptitle("Distribution of Movie vs TV Show")

type_counts = data['type'].value_counts()
ax.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%')
ax.set_title('Distribution of Movie vs TV Show')
plt.show()
